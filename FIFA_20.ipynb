# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
df= pd.read_csv('players_20.csv')

df.shape
pd.set_option('display.max_columns',104)
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  overall  potential  \
# ...

# %%
df['overall']
# Out:
# 0        94
# 1        93
# 2        92
# 3        91
# 4        91
#          ..
# 18273    48
# 18274    48
# 18275    48
# 18276    48
# 18277    48
# Name: overall, Length: 18278, dtype: int64

# %% [markdown]
# ### Histogram

# %%
bins=[40,50,60,70,80,90,100]
#plt.figure(figsize=(8,20))
plt.hist(df['overall'],bins =bins,color='#51db74')

plt.title('players rating',fontdict={'fontsize':20})
plt.xlabel('rating')
plt.ylabel('numbers of players')
plt.xticks(bins)
plt.show()

# %%
df['overall'].value_counts().head()
# Out:
# 66    1141
# 64    1138
# 65    1124
# 68    1068
# 67    1065
# Name: overall, dtype: int64

# %% [markdown]
# ### Pie Chart

# %%
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  overall  potential  \
# ...

# %%
left= df.loc[df['preferred_foot']=='Left'].count()[0]
right= df.loc[df['preferred_foot']=='Right'].count()[0]

# %%
right
# Out:
# 13960

# %%
left
# Out:
# 4318

# %%
labels=['Left','Right']
colors=['green','#51db74']
plt.pie([left,right], labels =labels,colors=colors,autopct='%.2f %%')
plt.title('foot preference',fontdict={'fontsize':20,'fontweight':'bold'})

plt.show()

# %%
df['weight_kg']
# Out:
# 0        72
# 1        83
# 2        68
# 3        87
# 4        74
#          ..
# 18273    79
# 18274    66
# 18275    75
# 18276    74
# 18277    78
# Name: weight_kg, Length: 18278, dtype: int64

# %%
light=df.loc[df['weight_kg']<60].count()[0]
light_med=df.loc[(df['weight_kg']>=60)&(df['weight_kg']<65)].count()[0]
medium=df.loc[(df['weight_kg']>=65)&(df['weight_kg']<75)].count()[0]
heavy_med=df.loc[(df['weight_kg']>=75)&(df['weight_kg']<85)].count()[0]
heavy=df.loc[df['weight_kg']>=85].count()[0]

plt.figure(dpi=100)
weights=[light,light_med,medium,heavy_med,heavy]
labels=['under 60','60 to 64','65 to 74','75 to 84','85 or above']
explode=(0.5,0.4,0,0,0.4)
plt.style.use('ggplot')
plt.title('weights comparison of players in kg',fontdict={'fontweight':'bold'})
plt.pie(weights,labels=labels ,autopct='%.2f %%',pctdistance=0.8,explode=explode)

plt.show()

# %%
top_clubs= df.groupby('club')['overall'].mean().sort_values(ascending=False).head(10)
top_clubs
# Out:
# club
# FC Bayern München      81.304348
# Real Madrid            80.121212
# Juventus               80.060606
# Uruguay                78.608696
# FC Barcelona           78.363636
# Netherlands            78.000000
# Colombia               78.000000
# Mexico                 78.000000
# Bayer 04 Leverkusen    77.280000
# Chelsea                77.060606
# Name: overall, dtype: float64

# %%
filt=df['club'] == df['nationality']
filt.value_counts()
# Out:
# False    18045
# True       233
# dtype: int64

# %%
df.loc[filt,'overall']=0.0
top_clubs= df.groupby('club')['overall'].mean().sort_values(ascending=False).head(10)
top_clubs
# Out:
# club
# FC Bayern München      81.304348
# Real Madrid            80.121212
# Juventus               80.060606
# FC Barcelona           78.363636
# Bayer 04 Leverkusen    77.280000
# Chelsea                77.060606
# Manchester City        77.000000
# Napoli                 76.870968
# Manchester United      76.848485
# Tottenham Hotspur      76.484848
# Name: overall, dtype: float64

# %%
df1=pd.DataFrame(top_clubs)
df1
# Out:
#                        overall
# club
# FC Bayern München    81.304348
# Real Madrid          80.121212
# Juventus             80.060606
# FC Barcelona         78.363636
# Bayer 04 Leverkusen  77.280000
# Chelsea              77.060606
# Manchester City      77.000000
# Napoli               76.870968
# Manchester United    76.848485
# Tottenham Hotspur    76.484848

# %%
clubs=df1.index.tolist()
clubs
# Out:
# ['FC Bayern München',
#  'Real Madrid',
#  'Juventus',
#  'FC Barcelona',
#  'Bayer 04 Leverkusen',
#  'Chelsea',
#  'Manchester City',
#  'Napoli',
#  'Manchester United',
#  'Tottenham Hotspur']

# %%
rating=top_clubs.tolist()
rating
# Out:
# [81.30434782608695,
#  80.12121212121212,
#  80.06060606060606,
#  78.36363636363636,
#  77.28,
#  77.06060606060606,
#  77.0,
#  76.87096774193549,
#  76.84848484848484,
#  76.48484848484848]

# %%
clubs=['FC Bayern München',
 'Real Madrid',
 'Juventus',
 'FC Barcelona',
 'Bayer 04 Leverkusen',
 'Chelsea',
 'Manchester City',
 'Napoli',
 'Manchester United',
 'Tottenham Hotspur']
rating=[81.30434782608695,
 80.12121212121212,
 80.06060606060606,
 78.36363636363636,
 77.28,
 77.06060606060606,
 77.0,
 76.87096774193549,
 76.84848484848484,
 76.48484848484848]


colors=['#fc2003','#f7fafa','#0f0f0f','#120669','#0a0a0a','#1706d1','#0ad5f0','#0a8cf0','#f0210a','#ffffff']
hatch_colors=['white','yellow','white','#8c0046','red','white','white','yellow','black','#311d52']
plt.figure(figsize=(8,10),dpi=300)
plt.title('average rating of top clubs',fontdict={'fontweight':'bold','fontsize':20})
plt.xlabel('rating',fontdict={'fontweight':'bold'})
plt.ylabel('clubs',fontdict={'fontweight':'bold'})
bars=plt.barh(clubs,rating,color=colors)

for bar in bars:
    bar.set_hatch('|')
    bar.set_edgecolor(hatch_colors.pop(0))
    bar.set_linewidth(2)
    bar.set_label(clubs.pop(0))
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  overall  potential  \
# ...

# %%
df['club']
# Out:
# 0                         FC Barcelona
# 1                             Juventus
# 2                  Paris Saint-Germain
# 3                      Atlético Madrid
# 4                          Real Madrid
#                      ...
# 18273                 Beijing Renhe FC
# 18274                 Shanghai SIPG FC
# 18275           Hebei China Fortune FC
# 18276    Shanghai Greenland Shenhua FC
# 18277           Hebei China Fortune FC
# Name: club, Length: 18278, dtype: object

# %%
df1
# Out:
#                        overall
# club
# FC Bayern München    81.304348
# Real Madrid          80.121212
# Juventus             80.060606
# FC Barcelona         78.363636
# Bayer 04 Leverkusen  77.280000
# Chelsea              77.060606
# Manchester City      77.000000
# Napoli               76.870968
# Manchester United    76.848485
# Tottenham Hotspur    76.484848

# %%
clubs=df1.index.tolist()

new_filt=(df['club'].isin(clubs))
new_filt
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4         True
#          ...
# 18273    False
# 18274    False
# 18275    False
# 18276    False
# 18277    False
# Name: club, Length: 18278, dtype: bool

# %%
clubs
# Out:
# ['FC Bayern München',
#  'Real Madrid',
#  'Juventus',
#  'FC Barcelona',
#  'Bayer 04 Leverkusen',
#  'Chelsea',
#  'Manchester City',
#  'Napoli',
#  'Manchester United',
#  'Tottenham Hotspur']

# %%
nation_count=df.loc[new_filt,'nationality'].value_counts().head(10)
count=nation_count.tolist()
nationality=pd.DataFrame(nation_count)
country=nationality.index.tolist()

plt.figure(figsize=(10,4))
plt.title('nationality of players in top clubs',fontdict={'fontweight':'bold','fontsize':20})
plt.xlabel('number of players',fontdict={'fontweight':'bold'})
plt.ylabel('nationality',fontdict={'fontweight':'bold'})
plt.barh(country,count,color= '#409c60')
plt.xticks(count)


plt.show()

# %%
nation_count=df.loc[new_filt,'nationality'].value_counts().head(10)
count=nation_count.tolist()
nationality=pd.DataFrame(nation_count)
country=nationality.index.tolist()
explode=[0,0,0,0,0,0,0.3,0.4,0.4,0.4]
plt.title('% of nationality of the players in top clubs',fontdict={'fontweight':'bold','fontsize':20})
plt.style.use('ggplot')
plt.pie(count,labels= country,autopct='%.2f %%',pctdistance=0.8,explode=explode)
plt.show()
